# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Running cells with 'c:\Users\user\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/user/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
iris_data = pd.read_csv(r'C:\Users\user\Desktop\iris.csv')

# %%
iris_data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
iris_data.mean(axis = 0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10772\467334520.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.mean(axis = 0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
iris_data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
iris_data.plot()
# Out:
# <Axes: >

# %%
iris_data.plot(kind="bar")
# Out:
# <Axes: >

# %%
iris_data.plot.barh(stacked=True);

# %%
plt.scatter(iris_data['SL'],iris_data['PW'])
